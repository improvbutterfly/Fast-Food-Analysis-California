# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xlrd

# %%
data = pd.read_csv('text.csv', converters={'column1': lambda x: f"{x:05}"})

# %%
You Can do This , Works On all Versions of Pandas

pd.read_csv('filename.csv', dtype={'zero_column_name': object})
# Out:
#   File "<ipython-input-13-d15ef3017c97>", line 1
#     You Can do This , Works On all Versions of Pandas
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# https://stackoverflow.com/questions/13250046/how-to-keep-leading-zeros-in-a-column-when-reading-csv-with-pandas

# %%
# Load in csv
    fips_df = pd.read_excel('fips_county_codes.xlsx', dtype={'Fips': object})
    fips_df
# Out:
#    Fips             CA Counties
# 0   001          Alameda County
# 1   003           Alpine County
# 2   005           Amador County
# 3   007            Butte County
# 4   009        Calaveras County
# 5   011           Colusa County
# 6   013     Contra Costa County
# 7   015        Del Norte County
# 8   017        El Dorado County
# 9   019           Fresno County
# 10  021            Glenn County
# 11  023         Humboldt County
# 12  025         Imperial County
# 13  027             Inyo County
# 14  029             Kern County
# 15  031            Kings County
# 16  033             Lake County
# 17  035           Lassen County
# 18  037      Los Angeles County
# 19  039           Madera County
# 20  041            Marin County
# 21  043         Mariposa County
# 22  045        Mendocino County
# 23  047           Merced County
# 24  049            Modoc County
# 25  051             Mono County
# 26  053         Monterey County
# 27  055             Napa County
# ...

# %%
fips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fips         58 non-null     int64
#  1   CA Counties  58 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
for index, row in fips_df.iterrows():
    county = row["CA Counties"]
    county_split = county.split(" County")
    fips_df.loc[index, "County"] = str(county_split[0])
        
fips_df
# Out:
#    Fips             CA Counties           County
# 0   001          Alameda County          Alameda
# 1   003           Alpine County           Alpine
# 2   005           Amador County           Amador
# 3   007            Butte County            Butte
# 4   009        Calaveras County        Calaveras
# 5   011           Colusa County           Colusa
# 6   013     Contra Costa County     Contra Costa
# 7   015        Del Norte County        Del Norte
# 8   017        El Dorado County        El Dorado
# 9   019           Fresno County           Fresno
# 10  021            Glenn County            Glenn
# 11  023         Humboldt County         Humboldt
# 12  025         Imperial County         Imperial
# 13  027             Inyo County             Inyo
# 14  029             Kern County             Kern
# 15  031            Kings County            Kings
# 16  033             Lake County             Lake
# 17  035           Lassen County           Lassen
# ...

# %%
del fips_df["CA Counties"]

# %%
fips_df.to_csv (r'fips_modified.csv', index = False, header=True)

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 14000, 60000, 135000, 430000, 208

# Create labels for these bins
group_labels = ["0 to 199k", "200k to 399k", "400k to 599k", "600k to 799k", "800k to 999k", "1mil to 2mil",
                "2mil to 3mil", "3mil to 4mil", "4mil to 5mil", "5mil to 50mil"]

# %%
pd.cut(fips_df["Population"], bins, labels=group_labels).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-7538814ab5fe> in <module>
# ...

# %%
binning_endpoints=[14348, 63983, 134827, 426762, 2081313],

# %% [markdown]
# https://stackoverflow.com/questions/13250046/how-to-keep-leading-zeros-in-a-column-when-reading-csv-with-pandas

# %% [markdown]
# https://levelup.gitconnected.com/group-data-using-bins-and-categories-with-pandas-836c9c9bbd46
