# %%
import pandas as pd

# %%
raw_socioeconomic_data_df = pd.read_csv("./data/HealthData/socioeconomicstatus_vs_obesity.csv")
raw_socioeconomic_data_df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
california_data = raw_socioeconomic_data_df.loc[((raw_socioeconomic_data_df["LocationDesc"] == "California") & (raw_socioeconomic_data_df["Class"] == "Obesity / Weight Status"))]
california_data
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 2568        2011     2011           CA   California
# 2674        2012     2012           CA   California
# 2676        2012     2012           CA   California
# 2701        2011     2011           CA   California
# 2702        2011     2011           CA   California
# ...          ...      ...          ...          ...
# 50524       2016     2016           CA   California
# 50525       2016     2016           CA   California
# 50526       2016     2016           CA   California
# 50527       2016     2016           CA   California
# 50528       2016     2016           CA   California
#
#                                        Datasource                    Class  \
# 2568   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2674   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2676   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
california_data = california_data[["YearStart", "YearEnd", "LocationDesc", "Class", "Data_Value", "Sample_Size", "Age(years)", "Education", "Gender", "Income", "Race/Ethnicity"]]
california_data
# Out:
#        YearStart  YearEnd LocationDesc                    Class  Data_Value  \
# 2568        2011     2011   California  Obesity / Weight Status        27.6
# 2674        2012     2012   California  Obesity / Weight Status        25.0
# 2676        2012     2012   California  Obesity / Weight Status        23.8
# 2701        2011     2011   California  Obesity / Weight Status        23.8
# 2702        2011     2011   California  Obesity / Weight Status        23.1
# ...          ...      ...          ...                      ...         ...
# 50524       2016     2016   California  Obesity / Weight Status         9.6
# 50525       2016     2016   California  Obesity / Weight Status         NaN
# 50526       2016     2016   California  Obesity / Weight Status        38.2
# 50527       2016     2016   California  Obesity / Weight Status        29.4
# 50528       2016     2016   California  Obesity / Weight Status        28.4
#
# ...
