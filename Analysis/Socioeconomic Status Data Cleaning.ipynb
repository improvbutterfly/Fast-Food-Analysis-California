# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_socioeconomic_data_df = pd.read_csv("./data/CA_modified_data_for_socioeconomic_data.csv")
raw_socioeconomic_data_df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
california_data = raw_socioeconomic_data_df.loc[((raw_socioeconomic_data_df["LocationDesc"] == "California") 
                                                 & (raw_socioeconomic_data_df["Class"] == "Obesity / Weight Status"))]
california_data = california_data.rename({"LocationAbbr":"State (Abbreviation)",
                        "LocationDesc":"State",
                        "Datasource":"Source",
                        "Question":"Classification",
                        "Data_Value":"Obesity Percentage",
                        "Sample_Size":"Number of Samples",
                        "Education":"Level of Education"
                       }, axis='columns')

california_data.loc[("have obesity" in string for string in california_data["Classification"].astype("string")), "Have Obesity/Overweight Classification"] = "obesity"

california_data
# Out:
#        YearStart  YearEnd State (Abbreviation)       State  \
# 2568        2011     2011                   CA  California
# 2674        2012     2012                   CA  California
# 2676        2012     2012                   CA  California
# 2701        2011     2011                   CA  California
# 2702        2011     2011                   CA  California
# ...          ...      ...                  ...         ...
# 50524       2016     2016                   CA  California
# 50525       2016     2016                   CA  California
# 50526       2016     2016                   CA  California
# 50527       2016     2016                   CA  California
# 50528       2016     2016                   CA  California
#
#                                            Source                    Class  \
# 2568   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2674   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
california_data = california_data[["YearStart", "YearEnd", "State", "Class","Classification", "Obesity Percentage", "Number of Samples", "Age(years)", "Level of Education", "Gender", "Income", "Race/Ethnicity"]]
california_data
# Out:
#        YearStart  YearEnd       State                    Class Classification  \
# 2568        2011     2011  California  Obesity / Weight Status        obesity
# 2674        2012     2012  California  Obesity / Weight Status        obesity
# 2676        2012     2012  California  Obesity / Weight Status        obesity
# 2701        2011     2011  California  Obesity / Weight Status        obesity
# 2702        2011     2011  California  Obesity / Weight Status        obesity
# ...          ...      ...         ...                      ...            ...
# 50524       2016     2016  California  Obesity / Weight Status        obesity
# 50525       2016     2016  California  Obesity / Weight Status        obesity
# 50526       2016     2016  California  Obesity / Weight Status        obesity
# 50527       2016     2016  California  Obesity / Weight Status        obesity
# 50528       2016     2016  California  Obesity / Weight Status        obesity
#
# ...

# %%
age_ranges = california_data["Age(years)"].unique()
print(age_ranges)
education_levels = california_data["Level of Education"].unique()
print(education_levels)
gender = california_data["Gender"].unique()
print(gender)
income_ranges = california_data["Income"].unique()
print(income_ranges)
race_ethnicity = california_data["Race/Ethnicity"].unique()
print(race_ethnicity)
# Out:
# ['55 - 64' nan '18 - 24' '25 - 34' '35 - 44' '45 - 54' '65 or older']
# [nan 'Less than high school' 'High school graduate'
#  'Some college or technical school' 'College graduate']
# [nan 'Female' 'Male']
# [nan 'Less than $15,000' '$15,000 - $24,999' '$25,000 - $34,999'
#  '$35,000 - $49,999' '$50,000 - $74,999' '$75,000 or greater'
#  'Data not reported']
# [nan 'Non-Hispanic White' 'Non-Hispanic Black' 'Hispanic' 'Asian'
#  'Hawaiian/Pacific Islander' 'American Indian/Alaska Native'
#  '2 or more races' 'Other']

# %%
age_data = california_data.dropna(subset = ["Age(years)"])
age_data = age_data[["YearEnd", "State", "Class", "Classification", "Obesity Percentage", "Number of Samples", "Age(years)"]]
age_data.head(20)
# Out:
#       YearEnd       State                    Class Classification  \
# 2568     2011  California  Obesity / Weight Status        obesity
# 2708     2011  California  Obesity / Weight Status        obesity
# 2709     2011  California  Obesity / Weight Status        obesity
# 2710     2011  California  Obesity / Weight Status        obesity
# 2711     2011  California  Obesity / Weight Status        obesity
# 2712     2011  California  Obesity / Weight Status        obesity
# 2734     2011  California  Obesity / Weight Status     overweight
# 2735     2011  California  Obesity / Weight Status     overweight
# 2736     2011  California  Obesity / Weight Status     overweight
# 2737     2011  California  Obesity / Weight Status     overweight
# 2738     2011  California  Obesity / Weight Status     overweight
# 2739     2011  California  Obesity / Weight Status     overweight
# 2959     2012  California  Obesity / Weight Status        obesity
# ...

# %%
level_of_education_data = california_data.dropna(subset = ["Level of Education"])
level_of_education_data = level_of_education_data[["YearEnd", "State", "Class","Classification", "Obesity Percentage", "Number of Samples", "Level of Education"]]
level_of_education_data.head(20)
# Out:
#       YearEnd       State                    Class Classification  \
# 2704     2011  California  Obesity / Weight Status        obesity
# 2705     2011  California  Obesity / Weight Status        obesity
# 2706     2011  California  Obesity / Weight Status        obesity
# 2707     2011  California  Obesity / Weight Status        obesity
# 2730     2011  California  Obesity / Weight Status     overweight
# 2731     2011  California  Obesity / Weight Status     overweight
# 2732     2011  California  Obesity / Weight Status     overweight
# 2733     2011  California  Obesity / Weight Status     overweight
# 2955     2012  California  Obesity / Weight Status        obesity
# 2956     2012  California  Obesity / Weight Status        obesity
# 2957     2012  California  Obesity / Weight Status        obesity
# 2958     2012  California  Obesity / Weight Status        obesity
# 2982     2012  California  Obesity / Weight Status     overweight
# ...

# %%
gender_data = california_data.dropna(subset = ["Gender"])
gender_data = gender_data[["YearEnd", "State", "Class","Classification", "Obesity Percentage", "Number of Samples", "Gender"]]
gender_data.head(20)
# Out:
#        YearEnd       State                    Class Classification  \
# 2676      2012  California  Obesity / Weight Status        obesity
# 2702      2011  California  Obesity / Weight Status        obesity
# 2703      2011  California  Obesity / Weight Status        obesity
# 2728      2011  California  Obesity / Weight Status     overweight
# 2729      2011  California  Obesity / Weight Status     overweight
# 2954      2012  California  Obesity / Weight Status        obesity
# 2980      2012  California  Obesity / Weight Status     overweight
# 2981      2012  California  Obesity / Weight Status     overweight
# 3034      2013  California  Obesity / Weight Status        obesity
# 3035      2013  California  Obesity / Weight Status        obesity
# 3062      2013  California  Obesity / Weight Status     overweight
# 3063      2013  California  Obesity / Weight Status     overweight
# 3289      2014  California  Obesity / Weight Status        obesity
# ...

# %%
income_data = california_data.dropna(subset = ["Income"])
income_data = income_data[["YearEnd", "State", "Class","Classification", "Obesity Percentage", "Number of Samples", "Income"]]
income_data = income_data.loc[income_data["Income"] != "Data not reported"]
income_data.head(20)
# Out:
#       YearEnd       State                    Class Classification  \
# 2713     2011  California  Obesity / Weight Status        obesity
# 2714     2011  California  Obesity / Weight Status        obesity
# 2715     2011  California  Obesity / Weight Status        obesity
# 2716     2011  California  Obesity / Weight Status        obesity
# 2717     2011  California  Obesity / Weight Status        obesity
# 2718     2011  California  Obesity / Weight Status        obesity
# 2740     2011  California  Obesity / Weight Status     overweight
# 2741     2011  California  Obesity / Weight Status     overweight
# 2742     2011  California  Obesity / Weight Status     overweight
# 2743     2011  California  Obesity / Weight Status     overweight
# 2744     2011  California  Obesity / Weight Status     overweight
# 2745     2011  California  Obesity / Weight Status     overweight
# 2965     2012  California  Obesity / Weight Status        obesity
# ...

# %%
race_ethnicity_data = california_data.dropna(subset = ["Race/Ethnicity"])
race_ethnicity_data = race_ethnicity_data[["YearEnd", "State", "Class","Classification", "Obesity Percentage", "Number of Samples", "Race/Ethnicity"]]
race_ethnicity_data = race_ethnicity_data.dropna()
race_ethnicity_data.head(20)
# Out:
#       YearEnd       State                    Class Classification  \
# 2720     2011  California  Obesity / Weight Status        obesity
# 2721     2011  California  Obesity / Weight Status        obesity
# 2722     2011  California  Obesity / Weight Status        obesity
# 2723     2011  California  Obesity / Weight Status        obesity
# 2724     2011  California  Obesity / Weight Status        obesity
# 2725     2011  California  Obesity / Weight Status        obesity
# 2726     2011  California  Obesity / Weight Status        obesity
# 2747     2011  California  Obesity / Weight Status     overweight
# 2748     2011  California  Obesity / Weight Status     overweight
# 2749     2011  California  Obesity / Weight Status     overweight
# 2751     2011  California  Obesity / Weight Status     overweight
# 2752     2011  California  Obesity / Weight Status     overweight
# 2753     2011  California  Obesity / Weight Status     overweight
# ...

# %%
#we have data by age, education level, gender, income, and race/ethnicity. we need to generate graphs for all 
#these data points vs percent obesity, for years 2011 & 2016. Additionally, we are only concerned for those that
#fall into the "obese" category, not overweight

#we need to use pd.loc to filter data in years 2011 and 2016, as well as to get the data for only obese

#age data
age_data2011 = age_data.loc[((age_data["Classification"] == "obesity") & (age_data["YearEnd"] == 2011))]
age_data2016 = age_data.loc[((age_data["Classification"] == "obesity") & (age_data["YearEnd"] == 2016))]
#level of education
level_of_education_data2011 = level_of_education_data.loc[((level_of_education_data["Classification"] == "obesity") & (level_of_education_data["YearEnd"] == 2011))]
level_of_education_data2016 = level_of_education_data.loc[((level_of_education_data["Classification"] == "obesity") & (level_of_education_data["YearEnd"] == 2016))]
#gender data
gender_data2011 = gender_data.loc[((gender_data["Classification"] == "obesity") & (gender_data["YearEnd"] == 2011))]
gender_data2016 = gender_data.loc[((gender_data["Classification"] == "obesity") & (gender_data["YearEnd"] == 2016))]
#income data
income_data2011 = income_data.loc[((income_data["Classification"] == "obesity") & (income_data["YearEnd"] == 2011))]
income_data2016 = income_data.loc[((income_data["Classification"] == "obesity") & (income_data["YearEnd"] == 2016))]
#race data
race_ethnicity_data2011 = race_ethnicity_data.loc[((race_ethnicity_data["Classification"] == "obesity") & (race_ethnicity_data["YearEnd"] == 2011))]
race_ethnicity_data2016 = race_ethnicity_data.loc[((race_ethnicity_data["Classification"] == "obesity") & (race_ethnicity_data["YearEnd"] == 2016))]

# %%
age_data2011 = age_data.reindex([2708, 2709, 2710, 2711, 2568, 2712])
age_data2011
# Out:
#       YearEnd       State                    Class Classification  \
# 2708     2011  California  Obesity / Weight Status        obesity
# 2709     2011  California  Obesity / Weight Status        obesity
# 2710     2011  California  Obesity / Weight Status        obesity
# 2711     2011  California  Obesity / Weight Status        obesity
# 2568     2011  California  Obesity / Weight Status        obesity
# 2712     2011  California  Obesity / Weight Status        obesity
#
#       Obesity Percentage  Number of Samples   Age(years)
# 2708                14.5              902.0      18 - 24
# 2709                23.7             1826.0      25 - 34
# 2710                25.9             2578.0      35 - 44
# 2711                27.6             2969.0      45 - 54
# 2568                27.6             3520.0      55 - 64
# 2712                21.2             5293.0  65 or older

# %%
#now, we need to graph the data for each, starting with 2011 data

#AGE VS OBESITY
age_range_2011 = age_data2011["Age(years)"]
values_by_age2011 = age_data2011["Obesity Percentage"]
plt.bar(age_range_2011, values_by_age2011)
plt.xlabel('Age(years)')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Age in 2011")
plt.savefig("./output images/age_vs_obesity_2011.png")
plt.show()

# age_data2011.head()

# %%
#EDUCATION VS OBESITY
education_range_2011 = level_of_education_data2011["Level of Education"]
values_by_education_range2011 = level_of_education_data2011["Obesity Percentage"]
plt.bar(education_range_2011, values_by_education_range2011)
plt.xticks(education_range_2011, rotation = 15)
plt.xlabel("Level of Education")
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Level of Education in 2011")
plt.savefig("./output images/education_vs_obesity_2011.png")
plt.show()

# %%
#for output images sake, we will rename to shorten the length
LOE = ["Less than HS", "HS grad", "Some college", "College grad"]
education_range_2011 = level_of_education_data2011["Level of Education"]
values_by_education_range2011 = level_of_education_data2011["Obesity Percentage"]
plt.bar(LOE, values_by_education_range2011)
# plt.xticks(LOE, rotation = 15)
plt.xlabel("Level of Education")
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Level of Education in 2011")
plt.savefig("./output images/education_vs_obesity_2011.png")
plt.show()

# %%
#GENDER VS OBESITY
gender_range_2011 = gender_data2011["Gender"]
values_by_gender2011 = gender_data2011["Obesity Percentage"]
plt.bar(gender_range_2011, values_by_gender2011)
plt.xlabel('Gender')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Gender in 2011")
plt.savefig("./output images/gender_vs_obesity_2011.png")
plt.show()

# %%
#INCOME VS OBESITY
income_range_2011 = income_data2011["Income"]
values_by_income2011 = income_data2011["Obesity Percentage"]
plt.bar(income_range_2011, values_by_income2011)
plt.xticks(income_range_2011, rotation = 45)
plt.xlabel('Income')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Income in 2011")
plt.savefig("./output images/Income_vs_obesity_2011.png")
plt.show()

# %%
#RACE VS OBESITY
race_ethnicity_2011 = race_ethnicity_data2011["Race/Ethnicity"]
values_by_race2011 = race_ethnicity_data2011["Obesity Percentage"]
plt.bar(race_ethnicity_2011, values_by_race2011)
plt.xticks(race_ethnicity_2011, rotation = 70)
plt.xlabel('Race/Ethnicity')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Race/Ethnicity in 2011")
plt.savefig("./output images/race_vs_obesity_2011.png")
plt.show()

# %%
#for the 2016 data
age_range_2016 = age_data2016["Age(years)"]
values_by_age2016 = age_data2016["Obesity Percentage"]
plt.bar(age_range_2016, values_by_age2016)
plt.xlabel('Age(years)')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Age in 2016")
plt.savefig("./output images/age_vs_obesity_2016.png")
plt.show()

# %%
#EDUCATION VS OBESITY
#for graph visual sake
education_range_2016 = level_of_education_data2016["Level of Education"]
values_by_education_range2016 = level_of_education_data2016["Obesity Percentage"]
plt.bar(LOE, values_by_education_range2016)
# plt.xticks(education_range_2016, rotation = 15)
plt.xlabel("Level of Education")
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Level of Education in 2016")
plt.savefig("./output images/education_vs_obesity_2016.png")
plt.show()

# %%
#GENDER VS OBESITY
gender_range_2016 = gender_data2016["Gender"]
values_by_gender2016 = gender_data2016["Obesity Percentage"]
plt.bar(gender_range_2016, values_by_gender2016)
plt.xlabel('Gender')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Gender in 2016")
plt.savefig("./output images/gender_vs_obesity_2016.png")
plt.show()

# %%
#INCOME VS OBESITY
income_range_2016 = income_data2016["Income"]
values_by_income2016 = income_data2016["Obesity Percentage"]
plt.bar(income_range_2016, values_by_income2016)
plt.xticks(income_range_2016, rotation = 45)
plt.xlabel('Income')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Income in 2016")
plt.savefig("./output images/Income_vs_obesity_2016.png")
plt.show()

# %%
#RACE VS OBESITY
race_ethnicity_2016 = race_ethnicity_data2016["Race/Ethnicity"]
values_by_race2016 = race_ethnicity_data2016["Obesity Percentage"]
plt.bar(race_ethnicity_2016, values_by_race2016)
plt.xticks(race_ethnicity_2016, rotation = 70)
plt.xlabel('Race/Ethnicity')
plt.ylabel('Obesity Percentage')
plt.title("Percentage of Obese people by Race/Ethnicity in 2016")
plt.savefig("./output images/race_vs_obesity_2016.png")
plt.show()
