# %%
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import numpy as np

# %%
huge_df = pd.read_csv("data/census_health_ff_education.csv")
huge_df = huge_df.loc[huge_df["County"] != "Alpine"]
huge_df = huge_df.loc[huge_df["County"] != "Mono"]
huge_df.head()
list(huge_df.columns)
# Out:
# ['County',
#  'Household Income 2011',
#  'Population 2011',
#  'Median Age 2011',
#  'Per Capita Income 2011',
#  'Poverty Count 2011',
#  'Employed Persons Over 16 2011',
#  'Unemployed Persons Over 16 2011',
#  'Household Income 2016',
#  'Population 2016',
#  'Median Age 2016',
#  'Per Capita Income 2016',
#  'Poverty Count 2016',
#  'Employed Persons Over 16 2016',
#  'Unemployed Persons Over 16 2016',
#  'Fast-food restaurants, 2011',
#  'Fast-food restaurants, 2016',
#  'Fast-food restaurants (% change), 2011-16',
#  'Fast-food restaurants/10,000 pop, 2011',
#  'Fast-food restaurants/10,000 pop, 2016',
#  'Fast-food restaurants/1,000 pop (% change), 2011-16',
#  'Obesity 2011 %',
#  'Obesity 2016 %',
#  'New Diabetes per 1k : 2011',
#  'New Diabetes per 1k : 2016',
#  'Diagnosed Diabetes 2011 %',
#  'Diagnosed Diabetes 2016 %',
#  'Population 2012',
#  'No Education 2012',
#  'High School Education 2012',
#  'GED education 2012',
#  'Associate Education 2012',
# ...

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Obesity 2011 %"])
plt.title("Fast Food restaurants/10,000 pop vs Obesity Rate 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Obesity Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Obesity 2011 %"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_obesity_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.3588707718009065
# R-squared value: 0.1287882308529783

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Obesity 2016 %"])
plt.title("Fast Food restaurants/10,000 pop vs Obesity Rate 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Obesity Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Obesity 2016 %"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_obesity_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.5707195340440635
# R-squared value: 0.32572078653947295

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Diagnosed Diabetes 2011 %"])
plt.title("Fast Food restaurants/10,000 pop vs Diagnosed Diabetes %, 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Diagnosed Diabetes (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Diagnosed Diabetes 2011 %"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_diabetes_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.15058799370788611
# R-squared value: 0.022676743848966348

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Diagnosed Diabetes 2016 %"])
plt.title("Fast Food restaurants/10,000 pop vs Diagnosed Diabetes %, 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Diagnosed Diabetes (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Diagnosed Diabetes 2016 %"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_diabetes_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.1791024539510132
# R-squared value: 0.03207768901127481

# %%
x = huge_df["Poverty Count 2016"]/ huge_df["Population 2016"] * 100
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], x)
plt.title("Fast Food restaurants/10,000 pop vs Poverty Rate 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Poverty Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], x)
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_poverty_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.2511834003081931
# R-squared value: 0.06309310059038598

# %%
x2 = huge_df["Poverty Count 2011"]/ huge_df["Population 2011"] * 100
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], x2)
plt.title("Fast Food restaurants/10,000 pop vs Poverty Rate 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Poverty Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], x2)
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_poverty_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.19659993120697924
# R-squared value: 0.03865153295058897

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["New Diabetes per 1k : 2016"])
plt.title("Fast Food restaurants/10,000 pop vs New Diabetes per 1k : 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("New Diabetes per 1k")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["New Diabetes per 1k : 2016"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_new_diabetes_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.4192249412583733
# R-squared value: 0.17574955137308654

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["New Diabetes per 1k : 2011"])
plt.title("Fast Food restaurants/10,000 pop vs New Diabetes per 1k : 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("New Diabetes per 1k")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["New Diabetes per 1k : 2011"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_new_diabetes_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.21390288619638717
# R-squared value: 0.04575444472314456

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Per Capita Income 2011"])
plt.title("Fast Food restaurants/10,000 pop vs Per Capita Income 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Per Capita Income 2011")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Per Capita Income 2011"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_income_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.397767101106243
# R-squared value: 0.15821866672246415

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Per Capita Income 2016"])
plt.title("Fast Food restaurants/10,000 pop vs Per Capita Income 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Per Capita Income 2016")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Per Capita Income 2016"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_income_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.5266912680213057
# R-squared value: 0.2774036918098909

# %%
plt.scatter(huge_df["Fast-food restaurants, 2011"], huge_df["Population 2011"])
plt.title("Fast Food restaurants vs Population 2011")
plt.xlabel("Fast Food restaurants")
plt.ylabel("Population")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants, 2011"], huge_df["Population 2011"])
linear_reg = vc_slope * huge_df["Fast-food restaurants, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants, 2011"],linear_reg,"--")
plt.savefig("charts/ff_population_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.9972661756369081
# R-squared value: 0.9945398250694645

# %%
plt.scatter(huge_df["Fast-food restaurants, 2016"], huge_df["Population 2016"])
plt.title("Fast Food restaurants vs Population 2016")
plt.xlabel("Fast Food restaurants")
plt.ylabel("Population")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants, 2016"], huge_df["Population 2016"])
linear_reg = vc_slope * huge_df["Fast-food restaurants, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants, 2016"],linear_reg,"--")
plt.savefig("charts/ff_population_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.9964866536107665
# R-squared value: 0.9929856508243837

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Household Income 2011"])
plt.title("Fast Food restaurants/10,000 vs Household Income 2011")
plt.xlabel("Fast Food restaurants")
plt.ylabel("Household Income")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], huge_df["Household Income 2011"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/ff_household_income_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.27834651117497866
# R-squared value: 0.07747678028328252

# %%
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Household Income 2016"])
plt.title("Fast Food restaurants/10,000 vs Household Income 2016")
plt.xlabel("Fast Food restaurants")
plt.ylabel("Household Income")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["Household Income 2016"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/ff_household_income_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.5526455240753612
# R-squared value: 0.3054170752805306

# %%
# Unemployment rate for over 16
unemployment_rate = huge_df["Unemployed Persons Over 16 2016"]/ (huge_df["Unemployed Persons Over 16 2016"] + huge_df["Employed Persons Over 16 2016"]) * 100
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], unemployment_rate)
plt.title("Fast Food restaurants/10,000 pop vs Unemployment Rate 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], unemployment_rate)
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_unemployment_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.5967618843920007
# R-squared value: 0.35612474666309163

# %%
# Unemployment rate for over 16
unemployment_rate = huge_df["Unemployed Persons Over 16 2011"]/ (huge_df["Unemployed Persons Over 16 2011"] + huge_df["Employed Persons Over 16 2011"]) * 100
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2011"], unemployment_rate)
plt.title("Fast Food restaurants/10,000 pop vs Unemployment Rate 2011")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2011"], unemployment_rate)
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2011"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2011"],linear_reg,"--")
plt.savefig("charts/food_unemployment_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.4074183720553898
# R-squared value: 0.16598972988826402

# %%
# College education rate
plt.scatter(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["College Rate 2016"])
plt.title("Fast Food restaurants/10,000 pop vs College Educated Rate 2016")
plt.xlabel("Fast Food restaurants/10,000 pop")
plt.ylabel("College Educated Rate (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Fast-food restaurants/10,000 pop, 2016"], huge_df["College Rate 2016"])
linear_reg = vc_slope * huge_df["Fast-food restaurants/10,000 pop, 2016"] + vc_int
plt.plot(huge_df["Fast-food restaurants/10,000 pop, 2016"],linear_reg,"--")
plt.savefig("charts/food_college_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.5725099432278867
# R-squared value: 0.32776763509479806

# %%
# College education vs. obesity rate
plt.scatter(huge_df["Obesity 2016 %"], huge_df["College Rate 2016"])
plt.title("Obesity Rate vs College Educated Rate 2016")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("College Educated Rate (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2016 %"], huge_df["College Rate 2016"])
linear_reg = vc_slope * huge_df["Obesity 2016 %"] + vc_int
plt.plot(huge_df["Obesity 2016 %"],linear_reg,"--")
plt.savefig("charts/obesity_college_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.8120860848378118
# R-squared value: 0.6594838091872056

# %%
# Per Capita Income vs. obesity rate
plt.scatter(huge_df["Obesity 2016 %"], huge_df["Per Capita Income 2016"])
plt.title("Obesity Rate vs Per Capita Income 2016")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Per Capita Income")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2016 %"], huge_df["Per Capita Income 2016"])
linear_reg = vc_slope * huge_df["Obesity 2016 %"] + vc_int
plt.plot(huge_df["Obesity 2016 %"],linear_reg,"--")
plt.savefig("charts/obesity_income_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.7532467718723405
# R-squared value: 0.5673806993361017

# %%
# Per Capita Income vs. obesity rate
plt.scatter(huge_df["Obesity 2011 %"], huge_df["Per Capita Income 2011"])
plt.title("Obesity Rate vs Per Capita Income 2011")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Per Capita Income")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2011 %"], huge_df["Per Capita Income 2011"])
linear_reg = vc_slope * huge_df["Obesity 2011 %"] + vc_int
plt.plot(huge_df["Obesity 2011 %"],linear_reg,"--")
plt.savefig("charts/obesity_income_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.7198794471097099
# R-squared value: 0.5182264183709816

# %%
# Unemployment rate for over 16 vs. Obesity Rate
unemployment_rate = huge_df["Unemployed Persons Over 16 2011"]/ (huge_df["Unemployed Persons Over 16 2011"] + huge_df["Employed Persons Over 16 2011"]) * 100
plt.scatter(huge_df["Obesity 2011 %"], unemployment_rate)
plt.title("Obesity Rate vs Unemployment Rate 2011")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2011 %"], unemployment_rate)
linear_reg = vc_slope * huge_df["Obesity 2011 %"] + vc_int
plt.plot(huge_df["Obesity 2011 %"],linear_reg,"--")
plt.savefig("charts/obesity_unemployment_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.25256780628906106
# R-squared value: 0.06379049677366867

# %%
# Unemployment rate for over 16 vs. Obesity Rate
unemployment_rate = huge_df["Unemployed Persons Over 16 2016"]/ (huge_df["Unemployed Persons Over 16 2016"] + huge_df["Employed Persons Over 16 2016"]) * 100
plt.scatter(huge_df["Obesity 2016 %"], unemployment_rate)
plt.title("Obesity Rate vs Unemployment Rate 2016")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2016 %"], unemployment_rate)
linear_reg = vc_slope * huge_df["Obesity 2016 %"] + vc_int
plt.plot(huge_df["Obesity 2016 %"],linear_reg,"--")
plt.savefig("charts/obesity_unemployment_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.5316690237368231
# R-squared value: 0.2826719508012666

# %%
# Unemployment rate for over 16 vs. Diagnosed Diabetes Rate
unemployment_rate = huge_df["Unemployed Persons Over 16 2011"]/ (huge_df["Unemployed Persons Over 16 2011"] + huge_df["Employed Persons Over 16 2011"]) * 100
plt.scatter(huge_df["Diagnosed Diabetes 2011 %"], unemployment_rate)
plt.title("Diagnosed Diabetes Rate vs Unemployment Rate 2011")
plt.xlabel("Diagnosed Diabetes Rate (%)")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Diagnosed Diabetes 2011 %"], unemployment_rate)
linear_reg = vc_slope * huge_df["Diagnosed Diabetes 2011 %"] + vc_int
plt.plot(huge_df["Diagnosed Diabetes 2011 %"],linear_reg,"--")
plt.savefig("charts/diabetes_unemployment_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.1790753346455579
# R-squared value: 0.032067975478418546

# %%
# Unemployment rate for over 16 vs. Diagnosed Diabetes Rate
unemployment_rate = huge_df["Unemployed Persons Over 16 2016"]/ (huge_df["Unemployed Persons Over 16 2016"] + huge_df["Employed Persons Over 16 2016"]) * 100
plt.scatter(huge_df["Diagnosed Diabetes 2016 %"], unemployment_rate)
plt.title("Diagnosed Diabetes Rate vs Unemployment Rate 2016")
plt.xlabel("Diagnosed Diabetes Rate (%)")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Diagnosed Diabetes 2016 %"], unemployment_rate)
linear_reg = vc_slope * huge_df["Diagnosed Diabetes 2016 %"] + vc_int
plt.plot(huge_df["Diagnosed Diabetes 2016 %"],linear_reg,"--")
plt.savefig("charts/diabetes_unemployment_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.29152483905513416
# R-squared value: 0.08498673178612187

# %%
# diagnosed diabetes rate vs. obesity rate
plt.scatter(huge_df["Obesity 2011 %"], huge_df["Diagnosed Diabetes 2011 %"])
plt.title("Obesity Rate vs Diagnosed Diabetes Rate 2011")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Diagnosed Diabetes (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2011 %"], huge_df["Diagnosed Diabetes 2011 %"])
linear_reg = vc_slope * huge_df["Obesity 2011 %"] + vc_int
plt.plot(huge_df["Obesity 2011 %"],linear_reg,"--")
plt.savefig("charts/obesity_diabetes_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.7379222293613767
# R-squared value: 0.5445292165856643

# %%
# diagnosed diabetes rate vs. obesity rate
plt.scatter(huge_df["Obesity 2016 %"], huge_df["Diagnosed Diabetes 2016 %"])
plt.title("Obesity Rate vs Diagnosed Diabetes Rate 2016")
plt.xlabel("Obesity Rate (%)")
plt.ylabel("Diagnosed Diabetes (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Obesity 2016 %"], huge_df["Diagnosed Diabetes 2016 %"])
linear_reg = vc_slope * huge_df["Obesity 2016 %"] + vc_int
plt.plot(huge_df["Obesity 2016 %"],linear_reg,"--")
plt.savefig("charts/obesity_diabetes_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.6541529316861476
# R-squared value: 0.42791605803358174

# %%
# College education vs. diagnosed diabetes rate
plt.scatter(huge_df["Diagnosed Diabetes 2016 %"], huge_df["College Rate 2016"])
plt.title("Diagnosed Diabetes Rate vs College Educated Rate 2016")
plt.xlabel("Diagnosed Diabetes Rate (%)")
plt.ylabel("College Educated Rate (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Diagnosed Diabetes 2016 %"], huge_df["College Rate 2016"])
linear_reg = vc_slope * huge_df["Diagnosed Diabetes 2016 %"] + vc_int
plt.plot(huge_df["Diagnosed Diabetes 2016 %"],linear_reg,"--")
plt.savefig("charts/diabetes_college_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.5725881773413534
# R-squared value: 0.32785722083109314

# %%
# Per Capita Income vs. diagnosed diabetes rate
plt.scatter(huge_df["Diagnosed Diabetes 2011 %"], huge_df["Per Capita Income 2011"])
plt.title("Diagnosed Diabetes Rate vs Per Capita Income 2011")
plt.xlabel("Diagnosed Diabetes Rate (%)")
plt.ylabel("Per Capita Income")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Diagnosed Diabetes 2011 %"], huge_df["Per Capita Income 2011"])
linear_reg = vc_slope * huge_df["Diagnosed Diabetes 2011 %"] + vc_int
plt.plot(huge_df["Diagnosed Diabetes 2011 %"],linear_reg,"--")
plt.savefig("charts/diabetes_income_2011.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.5667164483041154
# R-squared value: 0.3211675327784311

# %%
# Per Capita Income vs. diagnosed diabetes rate
plt.scatter(huge_df["Diagnosed Diabetes 2016 %"], huge_df["Per Capita Income 2016"])
plt.title("Diagnosed Diabetes Rate vs Per Capita Income 2016")
plt.xlabel("Diagnosed Diabetes Rate (%)")
plt.ylabel("Per Capita Income")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Diagnosed Diabetes 2016 %"], huge_df["Per Capita Income 2016"])
linear_reg = vc_slope * huge_df["Diagnosed Diabetes 2016 %"] + vc_int
plt.plot(huge_df["Diagnosed Diabetes 2016 %"],linear_reg,"--")
plt.savefig("charts/diabetes_income_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: -0.5094481839187359
# R-squared value: 0.2595374520980982

# %%
# College education vs. diagnosed diabetes rate
plt.scatter(huge_df["Per Capita Income 2016"], huge_df["College Rate 2016"])
plt.title("Per Capita Income vs College Educated Rate 2016")
plt.xlabel("Per Capita Income")
plt.ylabel("College Educated Rate (%)")
plt.grid(True)


(vc_slope, vc_int, vc_r, vc_p, vc_std_err) = stats.linregress(huge_df["Per Capita Income 2016"], huge_df["College Rate 2016"])
linear_reg = vc_slope * huge_df["Per Capita Income 2016"] + vc_int
plt.plot(huge_df["Per Capita Income 2016"],linear_reg,"--")
plt.savefig("charts/income_college_2016.png")
plt.show()
print(f"R value: {vc_r}")
print(f"R-squared value: {vc_r**2}")
# Out:
# R value: 0.9404077031123526
# R-squared value: 0.8843666480730507
